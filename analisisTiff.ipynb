# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
banda1Image = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B1.TIF"))
imagen_matriz = np.asarray(banda1Image)
print(imagen_matriz)
plt.imshow(banda1Image)
# Out:
# [[ 8416  8856  8493 ...  7290  7651  8430]
#  [ 8190  8435  8074 ...  7144  7364  8033]
#  [ 8285  8332  7717 ...  8382  7623  7297]
#  ...
#  [46597 47257 46424 ...  7294  7231  7113]
#  [44956 46416 47304 ...  7405  7277  7126]
#  [44359 45252 46896 ...  7408  7227  7126]]

# %%
banda1imagen2 = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B1.TIF"))
banda2imagen2 = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B2.TIF"))
banda3imagen2 = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B3.TIF"))
banda4imagen2 = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B4.TIF"))
banda5imagen2 = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B5.TIF"))
banda6imagen2 = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B6.TIF"))
banda7imagen2 = np.asarray(Image.open(r"LC09_L2SP_008057_20230203_20230311_02_T1_SR_B7.TIF"))
banda1_normimagen2 = banda1imagen2 / banda1imagen2.max()
banda2_normimagen2 = banda2imagen2 / banda2imagen2.max()
banda3_normimagen2 = banda3imagen2 / banda3imagen2.max()
banda4_normimagen2 = banda4imagen2 / banda4imagen2.max()
banda5_normimagen2 = banda5imagen2 / banda5imagen2.max()
banda6_normimagen2 = banda6imagen2 / banda6imagen2.max()
banda7_normimagen2 = banda7imagen2 / banda7imagen2.max()

verdadero_color = np.dstack((banda4_normimagen2, banda3_normimagen2, banda2_normimagen2))
plt.imshow(verdadero_color)

# %% [markdown]
# Con este codigo dercago las imagnes del servicio por espectro

# %%
import openeo

# First, we connect to the back-end and authenticate. 
con = openeo.connect("openeo.dataspace.copernicus.eu")
con.authenticate_oidc()

# Now that we are connected, we can initialize our datacube object with the area of interest 
# and the time range of interest using Sentinel 1 data.
datacube1 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B01"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)

datacube1.download("RGB1.TIF")
datacube2 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B02"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube2.download("RGB2.TIF")
datacube3 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B03"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube3.download("RGB3.TIF")
datacube4 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B04"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube4.download("RGB4.TIF")
datacube5 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B05"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube5.download("RGB5.TIF")
datacube6 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B06"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube6.download("RGB6.TIF")
datacube7 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B07"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube7.download("RGB7.TIF")
datacube8 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B08"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube8.download("RGB8.TIF")
datacube9 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B09"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube9.download("RGB9.TIF")

datacube11 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B011"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube11.download("RGB11.TIF")
datacube12 = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B012"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube12.download("RGB12.TIF")
# Out:
# Authenticated using refresh token.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 82
#      74 datacube9 = con.load_collection(
#      75     "SENTINEL2_L2A",
#      76     spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
#    (...)
#      79     max_cloud_cover=35,
#      80 )
#      81 datacube8.download("RGB9.TIF")
# ---> 82 datacube10 = con.load_collection(
#      83     "SENTINEL2_L2A",
#      84     spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
#      85     temporal_extent = ["2023-02-01", "2023-04-30"],
#      86     bands=["B010"],#["B02", "B04", "B08"],
#      87     max_cloud_cover=35,
#      88 )
#      89 datacube8.download("RGB10.TIF")
#      90 datacube11 = con.load_collection(
#      91     "SENTINEL2_L2A",
# ...

# %%
datacube8A = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent={"west": 5.14, "south": 51.17, "east": 5.17, "north": 51.19},
    temporal_extent = ["2023-02-01", "2023-04-30"],
    bands=["B8A"],#["B02", "B04", "B08"],
    max_cloud_cover=35,
)
datacube8A.download("RGB8A.TIF")
# Out:
# Authenticated using refresh token.

# %% [markdown]
# Para tener encuenta las bandas que tiene este tipo de satelite y hacer las combinaciones correctas

# %%
banda1 = np.asarray(Image.open(r"RGB1.TIF"))
banda2 = np.asarray(Image.open(r"RGB2.TIF"))
banda3 = np.asarray(Image.open(r"RGB3.TIF"))
banda4 = np.asarray(Image.open(r"RGB4.TIF"))
banda5 = np.asarray(Image.open(r"RGB5.TIF"))
banda6 = np.asarray(Image.open(r"RGB6.TIF"))
banda7 = np.asarray(Image.open(r"RGB7.TIF"))
banda8 = np.asarray(Image.open(r"RGB8.TIF"))
banda8A = np.asarray(Image.open(r"RGB8A.TIF"))
banda9 = np.asarray(Image.open(r"RGB9.TIF"))
banda11 = np.asarray(Image.open(r"RGB11.TIF"))
banda12 = np.asarray(Image.open(r"RGB12.TIF"))
banda1_norm = banda1 / banda1.max()
banda2_norm = banda2 / banda2.max()
banda3_norm = banda3 / banda3.max()
banda4_norm = banda4 / banda4.max()
banda5_norm = banda5 / banda5.max()
banda6_norm = banda6 / banda6.max()
banda7_norm = banda7 / banda7.max()
banda8_norm = banda8 / banda8.max()
banda8A_norm = banda8A / banda8A.max()
banda9_norm = banda9 / banda9.max()
banda11_norm = banda11 / banda11.max()
banda12_norm = banda12 / banda12.max()

# %%
infrarojo = np.dstack((banda8_norm, banda4_norm, banda3_norm))
plt.imshow(infrarojo)

# %%
agricola = np.dstack((banda11_norm, banda8A_norm, banda2_norm))
plt.imshow(agricola)

# %%
vegetacionVigorosa = np.dstack((banda8A_norm, banda11_norm, banda2_norm))
plt.imshow(agricola)

# %%
zona_urbana = np.dstack((banda12_norm, banda11_norm, banda4_norm))
plt.imshow(zona_urbana)

# %%
penetracion_atmosferica = np.dstack((banda12_norm, banda11_norm, banda8A_norm))
plt.imshow(penetracion_atmosferica)

# %%
colo_natural = np.dstack((banda4_norm, banda3_norm, banda2_norm))
plt.imshow(colo_natural)

# %%
analisis_vegetacion = np.dstack((banda8A_norm, banda11_norm, banda2_norm))
plt.imshow(analisis_vegetacion)

# %%
Un calculo importante para el proyecto evaluado en indice de vegetacion de diferencia normalizada

# %%
NDVI = (banda8A_norm-banda4_norm)/(banda8A_norm+banda4_norm)
plt.imshow(NDVI)

# %% [raw]
# GNDVI Índice de Vegetación de la Diferencia Normalizada Verde

# %%
GNDVI = (banda8_norm-banda3_norm)/(banda8_norm+banda3_norm)
plt.imshow(GNDVI)

# %%
Índice Diferencial de Agua Normalizado (NDWI)

# %%
NDWI  = (banda3_norm-banda11_norm)/(banda3_norm+banda11_norm)
plt.imshow(NDWI)

# %%
Índice de Nieve de Diferencia Normalizada (NDSI)

# %%
NDSI = (banda3_norm-banda11_norm)/(banda3_norm+banda11_norm)
plt.imshow(NDSI)

# %%
Índice de Vegetación Mejorado (EVI)

# %%
EVI = np.dstack((banda4_norm, banda5_norm, banda3_norm))
plt.imshow(EVI)

# %%
urbanismo = np.dstack((banda7_norm, banda4_norm, banda2_norm))
plt.imshow(urbanismo)

# %%
geo_cositas = np.dstack((banda5_norm, banda6_norm, banda7_norm))
plt.imshow(geo_cositas)
